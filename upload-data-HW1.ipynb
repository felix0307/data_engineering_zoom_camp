# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
# !ls ../../data
# Out:
# green_tripdata_2019-01.csv  taxi+_zone_lookup.csv  yellow_tripdata_2021-01.csv

# %%
df = pd.read_csv('../../data/green_tripdata_2019-01.csv', nrows=100)

# %%
df
# Out:
#     VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0          2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1          2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2          2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3          2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4          2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
# ..       ...                  ...                   ...                ...
# 95         2  2019-01-01 00:15:42   2019-01-01 00:41:04                  N
# 96         2  2019-01-01 00:21:28   2019-01-01 00:48:15                  N
# 97         2  2019-01-01 00:17:10   2019-01-01 00:23:34                  N
# 98         2  2019-01-01 00:25:01   2019-01-01 00:43:55                  N
# 99         2  2019-01-01 00:36:56   2019-01-01 00:43:50                  N
#
# ...

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df, name='green_taxi_data', con=engine))
# Out:
# CREATE TABLE green_taxi_data (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('../../data/green_tripdata_2019-01.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1             2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2             2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3             2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4             2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
# ...         ...                  ...                   ...                ...
# 99995         2  2019-01-06 09:56:09   2019-01-06 10:01:30                  N
# 99996         2  2019-01-06 09:12:49   2019-01-06 09:52:38                  N
# 99997         2  2019-01-06 09:02:06   2019-01-06 09:37:42                  N
# 99998         2  2019-01-06 09:55:01   2019-01-06 10:04:34                  N
# 99999         2  2019-01-06 09:59:04   2019-01-06 10:24:33                  N
#
# ...

# %%
df.head(n=0).to_sql(name='green_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='green_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 3.58 s, sys: 77.3 ms, total: 3.66 s
# Wall time: 6.85 s
# 1000

# %%
from time import time

# %%
while True: 
    t_start = time()

    df = next(df_iter)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    
    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk, took %.3f second' % (t_end - t_start))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Input In [25], in <cell line: 2>()
#       1 while True:
#       2     t_start = time()
# ----> 4     df = next(df_iter)
#       6     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#       7     df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1187, in TextFileReader.__next__(self)
#    1185 def __next__(self):
#    1186     try:
# -> 1187         return self.get_chunk()
#    1188     except StopIteration:
#    1189         self.close()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1284, in TextFileReader.get_chunk(self, size)
#    1282         raise StopIteration
#    1283     size = min(size, self.nrows - self._currow)
# -> 1284 return self.read(nrows=size)
#
# ...

# %%
# !wget https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv

# %%
df_zones = pd.read_csv('../../data/taxi+_zone_lookup.csv')

# %%
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')
# Out:
# 265

# %% [markdown]
# ### HW1

# %% [markdown]
# #### Question 1:  Knowing docker tags  ( Multiple choice)
# #### Which tag has the following text? - Write the image ID to the file

# %%
# !docker build --help
# Out:
# Usage:  docker build [OPTIONS] PATH | URL | -
#
# Build an image from a Dockerfile
#
# Options:
#       --add-host list           Add a custom host-to-IP mapping (host:ip)
#       --build-arg list          Set build-time variables
#       --cache-from strings      Images to consider as cache sources
#       --cgroup-parent string    Optional parent cgroup for the container
#       --compress                Compress the build context using gzip
#       --cpu-period int          Limit the CPU CFS (Completely Fair
#                                 Scheduler) period
#       --cpu-quota int           Limit the CPU CFS (Completely Fair
#                                 Scheduler) quota
#   -c, --cpu-shares int          CPU shares (relative weight)
#       --cpuset-cpus string      CPUs in which to allow execution (0-3, 0,1)
#       --cpuset-mems string      MEMs in which to allow execution (0-3, 0,1)
#       --disable-content-trust   Skip image verification (default true)
# ...

# %% [markdown]
# ### >>>       --iidfile string          Write the image ID to the file

# %% [markdown]
# #### Question 2:  Understanding docker first run  (Multiple choice)
# #### How many python packages/modules are installed?

# %%
# !docker exec dd4e5f132297 pip list
# Out:
# Package    Version
# ---------- -------
# pip        21.2.4
# setuptools 57.5.0
# wheel      0.37.0
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/usr/local/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# #### Question 3:  How many taxi trips were totally made on January 15?
# #### How many taxi trips were totally made on January 15?

# %%
date = '2019-01-15'
query = """select count(*) from green_taxi_data where lpep_pickup_datetime::date='2019-01-15'"""
pd.read_sql(query, engine)['count'][0]
# Out:
# 20689

# %% [markdown]
# #### Question 4: Largest trip for each day (Multiple choice)
# #### Which was the day with the largest trip distance?

# %%
query = """SELECT round(max(trip_distance)), lpep_date FROM (select trip_distance, date_trunc('day', lpep_pickup_datetime) as lpep_date from green_taxi_data group by lpep_pickup_datetime, trip_distance) as t
GROUP BY lpep_date"""

# %%
# %%time
pd.read_sql(query, engine).sort_values(by="round", ascending=False).values[0][1]
# Out:
# CPU times: user 0 ns, sys: 9.91 ms, total: 9.91 ms
# Wall time: 514 ms
# Timestamp('2019-01-15 00:00:00')

# %% [markdown]
# #### Question 5: The number of passengers  (Multiple choice)
# #### In 2019-01-01 how many trips had 2 and 3 passengers?

# %%
query = """select passenger_count from green_taxi_data where lpep_pickup_datetime::date='2019-01-01'"""
sub_df = pd.read_sql(query, engine)

# %%
sub_df[sub_df['passenger_count']==2].shape[0], sub_df[sub_df['passenger_count']==3].shape[0]
# Out:
# (1282, 254)

# %% [markdown]
# #### Question 6: Largest tip (Multiple choice)???????????
# #### For the passengers picked up in the Astoria Zone which was the drop up zone that had the largest tip?

# %%
zone_df = pd.read_sql("select * from zones", engine)

# %%
zone_df[zone_df['Zone']=='Astoria']
# Out:
#    index  LocationID Borough     Zone service_zone
# 6      6           7  Queens  Astoria    Boro Zone

# %%
query = """select from zones, green_taxi_data where """
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 600000         2  2019-01-30 15:48:41   2019-01-30 15:57:31
# 600001         2  2019-01-30 15:29:04   2019-01-30 15:35:59
# 600002         2  2019-01-30 15:50:30   2019-01-30 15:56:54
# 600003         2  2019-01-30 16:15:39   2019-01-30 16:43:32
# 600004         2  2019-01-30 15:01:59   2019-01-30 15:18:49
# ...          ...                  ...                   ...
# 630913         2  2019-01-31 23:08:27   2019-01-31 23:22:59
# 630914         2  2019-01-31 23:21:26   2019-01-31 23:23:05
# 630915         2  2019-01-31 23:30:05   2019-01-31 23:36:14
# 630916         2  2019-01-31 23:59:58   2019-02-01 00:04:18
# 630917         2  2019-01-31 23:18:22   2019-01-31 23:26:06
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 600000                  N           1           260            82
# 600001                  N           1           166           151
# ...

# %%
import numpy as np
sub_df = df[df['PULocationID']==zone_df[zone_df.Zone=='Astoria'].LocationID.values[0]]
# Out:
#    index  LocationID Borough     Zone service_zone
# 6      6           7  Queens  Astoria    Boro Zone

# %%
df[df['DOLocationID']==zone_df[zone_df.Zone=='Astoria'].LocationID.values[0]].tip_amount.max()
# Out:
# 62.22

# %%
sub_df.iloc[sub_df.tip_amount.argmax()].DOLocationID
# Out:
# 7

# %%
sub_df[sub_df.tip_amount==10]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 601486         2  2019-01-30 16:03:21   2019-01-30 16:07:29
# 625741         1  2019-01-31 18:56:06   2019-01-31 19:15:36
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 601486                  N           1             7             7
# 625741                  N           1             7            42
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 601486                1           0.34          4.5    1.0      0.5
# 625741                1           5.00         18.5    1.0      0.5
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 601486        10.0          0.00        NaN                    0.3
# 625741        10.0          5.76        NaN                    0.3
#
#         total_amount  payment_type  trip_type  congestion_surcharge
# 601486         16.30             1          1                   0.0
# ...

# %%
zone_df[zone_df['LocationID']==47]
# Out:
#     index  LocationID Borough                Zone service_zone
# 46     46          47   Bronx  Claremont/Bathgate    Boro Zone
